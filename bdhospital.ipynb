# %% [markdown]
# <a href="https://colab.research.google.com/github/nadiduno/Data-Warehouse/blob/main/bdhospital.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Livrarias
import numpy as np
import pandas as pd

# %%
#Importando Dados
df_hospital = pd.read_csv('BDHospitalIlhaMare.csv')
df_hospital2 = pd.read_csv('Atendimentos.csv')
df_pacientes = pd.read_csv('Pacientes.csv')
#Informação da BD
df_hospita2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID            1 non-null      int64
#  1   Paciente      1 non-null      object
#  2   Sexo          1 non-null      object
#  3   CPF           1 non-null      object
#  4   SUS           1 non-null      object
#  5   Endereco      1 non-null      object
#  6   Telefone      1 non-null      object
#  7   ID_seg        1 non-null      int64
#  8   Andar         1 non-null      int64
#  9   Consultorio   1 non-null      int64
#  10  Medico        1 non-null      object
#  11  Especialista  1 non-null      object
#  12  Procedimento  1 non-null      object
#  13  Costo         1 non-null      int64
#  14  Data_Chegada  1 non-null      object
#  15  Data_Saida    1 non-null      object
#  16  Alta          1 non-null      object
# dtypes: int64(5), object(12)
# memory usage: 264.0+ bytes

# %%
#Pacientes
df_pacientes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1402 entries, 0 to 1401
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          1402 non-null   int64
#  1   Paciente                    1402 non-null   object
#  2   Sexo                        1402 non-null   object
#  3   CPF                         1402 non-null   object
#  4   N# SUS                      1402 non-null   object
#  5   Endereco                    1402 non-null   object
#  6   Telefone                    1402 non-null   object
#  7   Seguro Medico               1402 non-null   int64
#  8   Medico de Atenção Primária  1402 non-null   object
# dtypes: int64(2), object(7)
# memory usage: 98.7+ KB

# %%
#Gerando dados para a tabela Atendimento
dados=[]
dados=df_hospital2
num_pac=len(1406)
num_ate=len(df_hospital2)
#Dados do Mês de maio
for i in range(1,32):
  dia1=str(i)+str('/')+str(5)+str('/2022')
  dia2=str(i)+str('/')+str(5)+str('/2022')
  num_ate += 1
  dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1,num_pac),'ID_blo':np.random.randint(7,9),
                'ID_med':np.random.randint(1,35),'ID_pro':21,'Data_Chegada':dia1,'Data_Saida':dia2,'Alta':'Si'}
  dados = dados.append(dicionario,ignore_index=True)

  if i<29:
    #Cardiologia - Cirugia
    num_ate += 1
    dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1,num_pac),'ID_blo':56,'ID_med':np.random.randint(49,50),'ID_pro':np.random.randint(79,86),'Data_Chegada':dia1,'Data_Saida':str(i+3)+str('/')+str(1)+str('/2022'),'Alta':'Si'}
    dados = dados.append(dicionario,ignore_index=True)
    #Oftalmologia - Cirugia
    num_ate += 1
    dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1,num_pac),'ID_blo':57,'ID_med':np.random.randint(51,53),'ID_pro':np.random.randint(87,100),'Data_Chegada':dia1,'Data_Saida':str(i+2)+str('/')+str(1)+str('/2022'),'Alta':'Si'}
    dados = dados.append(dicionario,ignore_index=True)
    #Oncologia - Cirugia e Quimioterapia
    num_ate += 1
    dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1,num_pac),'ID_blo':np.random.randint(54,55),'ID_med':np.random.randint(54,61),'ID_pro':np.random.randint(24,31),'Data_Chegada':dia1,'Data_Saida':str(i+2)+str('/')+str(1)+str('/2022'),'Alta':'Si'}
    dados = dados.append(dicionario,ignore_index=True)
    #Neumonologia - Cirugia
    num_ate += 1
    dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1,num_pac),'ID_blo':63,'ID_med':np.random.randint(62,64),'ID_pro':np.random.randint(101,104),'Data_Chegada':dia1,'Data_Saida':str(i+1)+str('/')+str(1)+str('/2022'),'Alta':'Si'}
    dados = dados.append(dicionario,ignore_index=True)
    #Infectologia - Cirugia
    num_ate += 1
    dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1,num_pac),'ID_blo':np.random.randint(124,125),'ID_med':np.random.randint(65,66),'ID_pro':np.random.randint(111,118),'Data_Chegada':dia1,'Data_Saida':str(i)+str('/')+str(1)+str('/2022'),'Alta':'Si'}
    dados = dados.append(dicionario,ignore_index=True)
    #Plástica - Cirugia
    num_ate += 1
    dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1,num_pac),'ID_blo':62,'ID_med':np.random.randint(67,69),'ID_pro':np.random.randint(53,62),'Data_Chegada':dia1,'Data_Saida':str(i+2)+str('/')+str(1)+str('/2022'),'Alta':'Si'}
    dados = dados.append(dicionario,ignore_index=True)
    #CODVID
    num_ate += 1
    dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1,num_pac),'ID_blo':np.random.randint(10,12),'ID_med':np.random.randint(1,35),'ID_pro':8,'Data_Chegada':dia1,'Data_Saida':str(i+2)+str('/')+str(1)+str('/2022'),'Alta':'Si'}
    dados = dados.append(dicionario,ignore_index=True)
    #Ortopedia - Cirugia
    num_ate += 1
    dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1,num_pac),'ID_blo':53,'ID_med':np.random.randint(43,45),'ID_pro':np.random.randint(45,52),'Data_Chegada':dia1,'Data_Saida':str(i+1)+str('/')+str(1)+str('/2022'),'Alta':'Si'}
    dados = dados.append(dicionario,ignore_index=True)
  #Ginecologia e obstetrícia - Cirugia
  #Solo Mujeres para Parto e Ceraria Pacientes(31-43)
  if i<=7:
    #3 Cirugias por dia
    num_ate += 1
    dicionario = {'ID_ate':num_ate,'ID_pac':i+30,'ID_blo':np.random.randint(58,61),'ID_med':np.random.randint(38,42),'ID_pro':np.random.randint(22,23),'Data_Chegada':dia1,'Data_Saida':str(i+3)+str('/')+str(1)+str('/2022'),'Alta':'Si'}
    dados = dados.append(dicionario,ignore_index=True)
    if i<=3:
      num_ate += 1
      dicionario = {'ID_ate':num_ate,'ID_pac':(i+30)+7,'ID_blo':np.random.randint(58,61),'ID_med':np.random.randint(38,42),'ID_pro':np.random.randint(22,23),'Data_Chegada':dia1,'Data_Saida':str(i+3)+str('/')+str(1)+str('/2022'),'Alta':'Si'}
      dados = dados.append(dicionario,ignore_index=True)
      num_ate += 1
      dicionario = {'ID_ate':num_ate,'ID_pac':(i+30)+10,'ID_blo':np.random.randint(58,61),'ID_med':np.random.randint(38,42),'ID_pro':np.random.randint(22,23),'Data_Chegada':dia1,'Data_Saida':str(i+3)+str('/')+str(1)+str('/2022'),'Alta':'Si'}
      dados = dados.append(dicionario,ignore_index=True)
  for j in range(1,30):
    if j<3:
      #Psiquiatria - Tratamento
      num_ate += 1
      dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1,num_pac),'ID_blo':np.random.randint(51,52),'ID_med':np.random.randint(36,37),'ID_pro':np.random.randint(105,110),'Data_Chegada':dia1,'Data_Saida':dia1,'Alta':'Si'}
      dados = dados.append(dicionario,ignore_index=True)
    if j<=4 :
      #Girugia Geral
      num_ate += 1
      dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1,num_pac),'ID_blo':np.random.randint(10,12),'ID_med':np.random.randint(1,35),'ID_pro':np.random.randint(1,8),'Data_Chegada':dia1,'Data_Saida':str(j)+str('/')+str(1)+str('/2022'),'Alta':'Si'}
      dados = dados.append(dicionario,ignore_index=True)
    if i <= 6:
      #Ortopedia - Consulta
      num_ate += 1
      dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1,num_pac),'ID_blo':np.random.randint(47,48),'ID_med':np.random.randint(43,45),'ID_pro':13,'Data_Chegada':dia1,'Data_Saida':dia2,'Alta':'Si'}
      dados = dados.append(dicionario,ignore_index=True)
      #Pediatria - Consulta
      num_ate += 1
      dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1330,1406),'ID_blo':np.random.randint(4,6),'ID_med':np.random.randint(46,48),'ID_pro':11,'Data_Chegada':dia1,'Data_Saida':dia2,'Alta':'Si'}
      dados = dados.append(dicionario,ignore_index=True)
    if i <= 7:
      #Psiquiatria - Consulta
      num_ate += 1
      dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1,num_pac),'ID_blo':np.random.randint(51,52),'ID_med':np.random.randint(36,37),'ID_pro':14,'Data_Chegada':dia1,'Data_Saida':dia2,'Alta':'Si'}
      dados = dados.append(dicionario,ignore_index=True)
      #Ginecologia e obstetrícia - Consulta
      num_ate += 1
      dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1,num_pac),'ID_blo':np.random.randint(44,46),'ID_med':np.random.randint(38,42),'ID_pro':15,'Data_Chegada':dia1,'Data_Saida':dia2,'Alta':'Si'}
      dados = dados.append(dicionario,ignore_index=True)
    if i <= 12:
      #Cardiologia - Consulta
      num_ate += 1
      dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1,num_pac),'ID_blo':np.random.randint(42,43),'ID_med':np.random.randint(49,50),'ID_pro':20,'Data_Chegada':dia1,'Data_Saida':dia2,'Alta':'Si'}
      dados = dados.append(dicionario,ignore_index=True)
      #Oftalmologia - Consulta
      num_ate += 1
      dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1,num_pac),'ID_blo':np.random.randint(49,50),'ID_med':np.random.randint(51,53),'ID_pro':12,'Data_Chegada':dia1,'Data_Saida':dia2,'Alta':'Si'}
      dados = dados.append(dicionario,ignore_index=True)
      #Oncologia - Consulta
      num_ate += 1
      dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1,num_pac),'ID_blo':np.random.randint(120,123),'ID_med':np.random.randint(54,61),'ID_pro':16,'Data_Chegada':dia1,'Data_Saida':dia2,'Alta':'Si'}
      dados = dados.append(dicionario,ignore_index=True)
    if i<=18:
      #Infectologia - Consulta
      num_ate += 1
      dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1,num_pac),'ID_blo':np.random.randint(118,119),'ID_med':np.random.randint(65,66),'ID_pro':18,'Data_Chegada':dia1,'Data_Saida':dia2,'Alta':'Si'}
      dados = dados.append(dicionario,ignore_index=True)
      #Plástica - Consulta
      num_ate += 1
      dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1,num_pac),'ID_blo':np.random.randint(40,41),'ID_med':np.random.randint(67,69),'ID_pro':19,'Data_Chegada':dia1,'Data_Saida':dia2,'Alta':'Si'}
      dados = dados.append(dicionario,ignore_index=True)
    if i <= 29:
      #Radiografias e Imagem
      num_ate += 1
      dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1,num_pac),'ID_blo':np.random.randint(114,116),'ID_med':np.random.randint(54,61),'ID_pro':np.random.randint(63,78),'Data_Chegada':dia1,'Data_Saida':dia2,'Alta':'Si'}
      dados = dados.append(dicionario,ignore_index=True)
    if i<= 32:
      #Neumonologia - Consulta
      num_ate += 1
      dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1,num_pac),'ID_blo':117,'ID_med':np.random.randint(62,64),'ID_pro':17,'Data_Chegada':dia1,'Data_Saida':dia2,'Alta':'Si'}
      dados = dados.append(dicionario,ignore_index=True)
    if i<=25 :
      #Quimioterapia - 3 dias na semana
      pac = np.random.randint(1,num_pac)
      #Dialiais - 4 dias na semana
      pac2 = np.random.randint(1,num_pac)
      #Hemodiálise Portador Hiv - 3 dias na semana
      pac3 = np.random.randint(1,num_pac)
      if i==3 or i==10 or i==17 or i==24:
        d1=str(i)+str('/')+str(1)+str('/2022')
        d2=str(i)+str('/')+str(1)+str('/2022')
        num_ate += 1
        dicionario = {'ID_ate':num_ate,'ID_pac':pac,'ID_blo':np.random.randint(54,55),'ID_med':np.random.randint(54,61),'ID_pro':9,'Data_Chegada':d1,'Data_Saida':d2,'Alta':'Si'}
        dados = dados.append(dicionario,ignore_index=True)
        num_ate += 1
        dicionario = {'ID_ate':num_ate,'ID_pac':pac2,'ID_blo':np.random.randint(54,55),'ID_med':np.random.randint(54,61),'ID_pro':31,'Data_Chegada':d1,'Data_Saida':d2,'Alta':'Si'}
        dados = dados.append(dicionario,ignore_index=True)
        d1=str(i+1)+str('/')+str(1)+str('/2022')
        d2=str(i+1)+str('/')+str(1)+str('/2022')
        num_ate += 1
        dicionario = {'ID_ate':num_ate,'ID_pac':pac2,'ID_blo':np.random.randint(54,55),'ID_med':np.random.randint(54,61),'ID_pro':31,'Data_Chegada':d1,'Data_Saida':d2,'Alta':'Si'}
        dados = dados.append(dicionario,ignore_index=True)
        num_ate += 1
        dicionario = {'ID_ate':num_ate,'ID_pac':pac3,'ID_blo':np.random.randint(124,125),'ID_med':np.random.randint(65,66),'ID_pro':119,'Data_Chegada':d1,'Data_Saida':d2,'Alta':'Si'}
        dados = dados.append(dicionario,ignore_index=True)
        d1=str(i+2)+str('/')+str(1)+str('/2022')
        d2=str(i+2)+str('/')+str(1)+str('/2022')
        num_ate += 1
        dicionario = {'ID_ate':num_ate,'ID_pac':pac,'ID_blo':np.random.randint(54,55),'ID_med':np.random.randint(54,61),'ID_pro':9,'Data_Chegada':d1,'Data_Saida':d2,'Alta':'Si'}
        dados = dados.append(dicionario,ignore_index=True)
        num_ate += 1
        dicionario = {'ID_ate':num_ate,'ID_pac':pac2,'ID_blo':np.random.randint(54,55),'ID_med':np.random.randint(54,61),'ID_pro':31,'Data_Chegada':d1,'Data_Saida':d2,'Alta':'Si'}
        dados = dados.append(dicionario,ignore_index=True)
        num_ate += 1
        dicionario = {'ID_ate':num_ate,'ID_pac':pac3,'ID_blo':np.random.randint(124,125),'ID_med':np.random.randint(65,66),'ID_pro':119,'Data_Chegada':d1,'Data_Saida':d2,'Alta':'Si'}
        dados = dados.append(dicionario,ignore_index=True)
        d1=str(i+4)+str('/')+str(1)+str('/2022')
        d2=str(i+4)+str('/')+str(1)+str('/2022')
        num_ate += 1
        dicionario = {'ID_ate':num_ate,'ID_pac':pac,'ID_blo':np.random.randint(54,55),'ID_med':np.random.randint(54,61),'ID_pro':9,'Data_Chegada':d1,'Data_Saida':d2,'Alta':'Si'}
        dados = dados.append(dicionario,ignore_index=True)
        num_ate += 1
        dicionario = {'ID_ate':num_ate,'ID_pac':pac2,'ID_blo':np.random.randint(54,55),'ID_med':np.random.randint(54,61),'ID_pro':31,'Data_Chegada':d1,'Data_Saida':d2,'Alta':'Si'}
        dados = dados.append(dicionario,ignore_index=True)
        num_ate += 1
        dicionario = {'ID_ate':num_ate,'ID_pac':pac3,'ID_blo':np.random.randint(124,125),'ID_med':np.random.randint(65,66),'ID_pro':119,'Data_Chegada':d1,'Data_Saida':d2,'Alta':'Si'}
        dados = dados.append(dicionario,ignore_index=True)
#Pediatria - Cirugia ******** #Não temos no Hospital
print(dados)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-aa8bd9efa0bd> in <module>()
#       2 dados=[]
#       3 dados=df_hospital2
# ----> 4 num_pac=len(1406)
#       5 num_ate=len(df_hospital2)
#       6 #Dados do Mês de maio
#
# TypeError: object of type 'int' has no len()

# %%
#Mês de Fevereiro
for i in range(1,29):
  dia1=str(i)+str('/')+str(2)+str('/2022')
  dia2=str(i)+str('/')+str(2)+str('/2022')
  #Medicina Geral - Consulta
  num_ate += 1
  dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1,num_pac),'ID_blo':np.random.randint(7,9),'ID_med':np.random.randint(1,35),'ID_pro':21,'Data_Chegada':dia1,'Data_Saida':dia2,'Alta':'Si'}
  dados = dados.append(dicionario,ignore_index=True)
  if i<25:
    #Cardiologia - Cirugia
    num_ate += 1
    dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1,num_pac),'ID_blo':56,'ID_med':np.random.randint(49,50),'ID_pro':np.random.randint(79,86),'Data_Chegada':dia1,'Data_Saida':str(i+3)+str('/')+str(2)+str('/2022'),'Alta':'Si'}
    dados = dados.append(dicionario,ignore_index=True)
    #Oftalmologia - Cirugia
    num_ate += 1
    dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1,num_pac),'ID_blo':57,'ID_med':np.random.randint(51,53),'ID_pro':np.random.randint(87,100),'Data_Chegada':dia1,'Data_Saida':str(i+2)+str('/')+str(2)+str('/2022'),'Alta':'Si'}
    dados = dados.append(dicionario,ignore_index=True)
    #Oncologia - Cirugia e Quimioterapia
    num_ate += 1
    dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1,num_pac),'ID_blo':np.random.randint(54,55),'ID_med':np.random.randint(54,61),'ID_pro':np.random.randint(24,31),'Data_Chegada':dia1,'Data_Saida':str(i+2)+str('/')+str(2)+str('/2022'),'Alta':'Si'}
    dados = dados.append(dicionario,ignore_index=True)
    #Neumonologia - Cirugia
    num_ate += 1
    dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1,num_pac),'ID_blo':63,'ID_med':np.random.randint(62,64),'ID_pro':np.random.randint(101,104),'Data_Chegada':dia1,'Data_Saida':str(i+1)+str('/')+str(2)+str('/2022'),'Alta':'Si'}
    dados = dados.append(dicionario,ignore_index=True)
    #Infectologia - Cirugia
    num_ate += 1
    dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1,num_pac),'ID_blo':np.random.randint(124,125),'ID_med':np.random.randint(65,66),'ID_pro':np.random.randint(111,118),'Data_Chegada':dia1,'Data_Saida':str(i)+str('/')+str(2)+str('/2022'),'Alta':'Si'}
    dados = dados.append(dicionario,ignore_index=True)
    #Plástica - Cirugia
    num_ate += 1
    dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1,num_pac),'ID_blo':62,'ID_med':np.random.randint(67,69),'ID_pro':np.random.randint(53,62),'Data_Chegada':dia1,'Data_Saida':str(i+2)+str('/')+str(2)+str('/2022'),'Alta':'Si'}
    dados = dados.append(dicionario,ignore_index=True)
    #CODVID
    num_ate += 1
    dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1,num_pac),'ID_blo':np.random.randint(10,12),'ID_med':np.random.randint(1,35),'ID_pro':8,'Data_Chegada':dia1,'Data_Saida':str(i+2)+str('/')+str(2)+str('/2022'),'Alta':'Si'}
    dados = dados.append(dicionario,ignore_index=True)
    #Ortopedia - Cirugia
    num_ate += 1
    dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1,num_pac),'ID_blo':53,'ID_med':np.random.randint(43,45),'ID_pro':np.random.randint(45,52),'Data_Chegada':dia1,'Data_Saida':str(i+1)+str('/')+str(2)+str('/2022'),'Alta':'Si'}
    dados = dados.append(dicionario,ignore_index=True)
  #Ginecologia e obstetrícia - Cirugia
  #Solo Mujeres para Parto e Ceraria Pacientes(31-43)
  if i<=7:
    #3 Cirugias por dia
    num_ate += 1
    dicionario = {'ID_ate':num_ate,'ID_pac':i+30,'ID_blo':np.random.randint(58,61),'ID_med':np.random.randint(38,42),'ID_pro':np.random.randint(22,23),'Data_Chegada':dia1,'Data_Saida':str(i+3)+str('/')+str(2)+str('/2022'),'Alta':'Si'}
    dados = dados.append(dicionario,ignore_index=True)
    if i<=3:
      num_ate += 1
      dicionario = {'ID_ate':num_ate,'ID_pac':(i+30)+7,'ID_blo':np.random.randint(58,61),'ID_med':np.random.randint(38,42),'ID_pro':np.random.randint(22,23),'Data_Chegada':dia1,'Data_Saida':str(i+3)+str('/')+str(2)+str('/2022'),'Alta':'Si'}
      dados = dados.append(dicionario,ignore_index=True)
      num_ate += 1
      dicionario = {'ID_ate':num_ate,'ID_pac':(i+30)+10,'ID_blo':np.random.randint(58,61),'ID_med':np.random.randint(38,42),'ID_pro':np.random.randint(22,23),'Data_Chegada':dia1,'Data_Saida':str(i+3)+str('/')+str(2)+str('/2022'),'Alta':'Si'}
      dados = dados.append(dicionario,ignore_index=True)
  for j in range(1,27):
    if j<3:
      #Psiquiatria - Tratamento
      num_ate += 1
      dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1,num_pac),'ID_blo':np.random.randint(51,52),'ID_med':np.random.randint(36,37),'ID_pro':np.random.randint(105,110),'Data_Chegada':dia1,'Data_Saida':dia1,'Alta':'Si'}
      dados = dados.append(dicionario,ignore_index=True)
    if j<=4 :
      #Girugia Geral
      num_ate += 1
      dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1,num_pac),'ID_blo':np.random.randint(10,12),'ID_med':np.random.randint(1,35),'ID_pro':np.random.randint(1,8),'Data_Chegada':dia1,'Data_Saida':str(j)+str('/')+str(2)+str('/2022'),'Alta':'Si'}
      dados = dados.append(dicionario,ignore_index=True)
    if i <= 6:
      #Ortopedia - Consulta
      num_ate += 1
      dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1,num_pac),'ID_blo':np.random.randint(47,48),'ID_med':np.random.randint(43,45),'ID_pro':13,'Data_Chegada':dia1,'Data_Saida':dia2,'Alta':'Si'}
      dados = dados.append(dicionario,ignore_index=True)
      #Pediatria - Consulta
      num_ate += 1
      dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1330,1406),'ID_blo':np.random.randint(4,6),'ID_med':np.random.randint(46,48),'ID_pro':11,'Data_Chegada':dia1,'Data_Saida':dia2,'Alta':'Si'}
      dados = dados.append(dicionario,ignore_index=True)
    if i <= 7:
      #Psiquiatria - Consulta
      num_ate += 1
      dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1,num_pac),'ID_blo':np.random.randint(51,52),'ID_med':np.random.randint(36,37),'ID_pro':14,'Data_Chegada':dia1,'Data_Saida':dia2,'Alta':'Si'}
      dados = dados.append(dicionario,ignore_index=True)
      #Ginecologia e obstetrícia - Consulta
      num_ate += 1
      dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1,num_pac),'ID_blo':np.random.randint(44,46),'ID_med':np.random.randint(38,42),'ID_pro':15,'Data_Chegada':dia1,'Data_Saida':dia2,'Alta':'Si'}
      dados = dados.append(dicionario,ignore_index=True)
    if i <= 12:
      #Cardiologia - Consulta
      num_ate += 1
      dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1,num_pac),'ID_blo':np.random.randint(42,43),'ID_med':np.random.randint(49,50),'ID_pro':20,'Data_Chegada':dia1,'Data_Saida':dia2,'Alta':'Si'}
      dados = dados.append(dicionario,ignore_index=True)
      #Oftalmologia - Consulta
      num_ate += 1
      dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1,num_pac),'ID_blo':np.random.randint(49,50),'ID_med':np.random.randint(51,53),'ID_pro':12,'Data_Chegada':dia1,'Data_Saida':dia2,'Alta':'Si'}
      dados = dados.append(dicionario,ignore_index=True)
      #Oncologia - Consulta
      num_ate += 1
      dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1,num_pac),'ID_blo':np.random.randint(120,123),'ID_med':np.random.randint(54,61),'ID_pro':16,'Data_Chegada':dia1,'Data_Saida':dia2,'Alta':'Si'}
      dados = dados.append(dicionario,ignore_index=True)
    if i<=18:
      #Infectologia - Consulta
      num_ate += 1
      dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1,num_pac),'ID_blo':np.random.randint(118,119),'ID_med':np.random.randint(65,66),'ID_pro':18,'Data_Chegada':dia1,'Data_Saida':dia2,'Alta':'Si'}
      dados = dados.append(dicionario,ignore_index=True)
      #Plástica - Consulta
      num_ate += 1
      dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1,num_pac),'ID_blo':np.random.randint(40,41),'ID_med':np.random.randint(67,69),'ID_pro':19,'Data_Chegada':dia1,'Data_Saida':dia2,'Alta':'Si'}
      dados = dados.append(dicionario,ignore_index=True)
    if i <= 27:
      #Radiografias e Imagem
      num_ate += 1
      dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1,num_pac),'ID_blo':np.random.randint(114,116),'ID_med':np.random.randint(54,61),'ID_pro':np.random.randint(63,78),'Data_Chegada':dia1,'Data_Saida':dia2,'Alta':'Si'}
      dados = dados.append(dicionario,ignore_index=True)
    if i<= 32:
      #Neumonologia - Consulta
      num_ate += 1
      dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1,num_pac),'ID_blo':117,'ID_med':np.random.randint(62,64),'ID_pro':17,'Data_Chegada':dia1,'Data_Saida':dia2,'Alta':'Si'}
      dados = dados.append(dicionario,ignore_index=True)
    if i<=25 :
      #Quimioterapia - 3 dias na semana
      pac = np.random.randint(1,num_pac)
      #Dialiais - 4 dias na semana
      pac2 = np.random.randint(1,num_pac)
      #Hemodiálise Portador Hiv - 3 dias na semana
      pac3 = np.random.randint(1,num_pac)
      if i==3 or i==10 or i==17 or i==24:
        d1=str(i)+str('/')+str(2)+str('/2022')
        d2=str(i)+str('/')+str(2)+str('/2022')
        num_ate += 1
        dicionario = {'ID_ate':num_ate,'ID_pac':pac,'ID_blo':np.random.randint(54,55),'ID_med':np.random.randint(54,61),'ID_pro':9,'Data_Chegada':d1,'Data_Saida':d2,'Alta':'Si'}
        dados = dados.append(dicionario,ignore_index=True)
        num_ate += 1
        dicionario = {'ID_ate':num_ate,'ID_pac':pac2,'ID_blo':np.random.randint(54,55),'ID_med':np.random.randint(54,61),'ID_pro':31,'Data_Chegada':d1,'Data_Saida':d2,'Alta':'Si'}
        dados = dados.append(dicionario,ignore_index=True)
        d1=str(i+1)+str('/')+str(2)+str('/2022')
        d2=str(i+1)+str('/')+str(2)+str('/2022')
        num_ate += 1
        dicionario = {'ID_ate':num_ate,'ID_pac':pac2,'ID_blo':np.random.randint(54,55),'ID_med':np.random.randint(54,61),'ID_pro':31,'Data_Chegada':d1,'Data_Saida':d2,'Alta':'Si'}
        dados = dados.append(dicionario,ignore_index=True)
        num_ate += 1
        dicionario = {'ID_ate':num_ate,'ID_pac':pac3,'ID_blo':np.random.randint(124,125),'ID_med':np.random.randint(65,66),'ID_pro':119,'Data_Chegada':d1,'Data_Saida':d2,'Alta':'Si'}
        dados = dados.append(dicionario,ignore_index=True)
        d1=str(i+2)+str('/')+str(2)+str('/2022')
        d2=str(i+2)+str('/')+str(2)+str('/2022')
        num_ate += 1
        dicionario = {'ID_ate':num_ate,'ID_pac':pac,'ID_blo':np.random.randint(54,55),'ID_med':np.random.randint(54,61),'ID_pro':9,'Data_Chegada':d1,'Data_Saida':d2,'Alta':'Si'}
        dados = dados.append(dicionario,ignore_index=True)
        num_ate += 1
        dicionario = {'ID_ate':num_ate,'ID_pac':pac2,'ID_blo':np.random.randint(54,55),'ID_med':np.random.randint(54,61),'ID_pro':31,'Data_Chegada':d1,'Data_Saida':d2,'Alta':'Si'}
        dados = dados.append(dicionario,ignore_index=True)
        num_ate += 1
        dicionario = {'ID_ate':num_ate,'ID_pac':pac3,'ID_blo':np.random.randint(124,125),'ID_med':np.random.randint(65,66),'ID_pro':119,'Data_Chegada':d1,'Data_Saida':d2,'Alta':'Si'}
        dados = dados.append(dicionario,ignore_index=True)
        d1=str(i+4)+str('/')+str(2)+str('/2022')
        d2=str(i+4)+str('/')+str(2)+str('/2022')
        num_ate += 1
        dicionario = {'ID_ate':num_ate,'ID_pac':pac,'ID_blo':np.random.randint(54,55),'ID_med':np.random.randint(54,61),'ID_pro':9,'Data_Chegada':d1,'Data_Saida':d2,'Alta':'Si'}
        dados = dados.append(dicionario,ignore_index=True)
        num_ate += 1
        dicionario = {'ID_ate':num_ate,'ID_pac':pac2,'ID_blo':np.random.randint(54,55),'ID_med':np.random.randint(54,61),'ID_pro':31,'Data_Chegada':d1,'Data_Saida':d2,'Alta':'Si'}
        dados = dados.append(dicionario,ignore_index=True)
        num_ate += 1
        dicionario = {'ID_ate':num_ate,'ID_pac':pac3,'ID_blo':np.random.randint(124,125),'ID_med':np.random.randint(65,66),'ID_pro':119,'Data_Chegada':d1,'Data_Saida':d2,'Alta':'Si'}
        dados = dados.append(dicionario,ignore_index=True)
#Pediatria - Cirugia ******** #Não temos no Hospital
print(dados)
# Out:
#        ID_ate  ID_pac  ID_blo  ID_med  ID_pro Data_Chegada Data_Saida Alta
# 0           1       1       7       1       7     1/1/2022   1/1/2022   Si
# 1           2    1163      10       5       8     1/1/2022   8/1/2022   Si
# 2           3     644      11      21       8     1/1/2022  15/1/2022   Si
# 3           4    1205      10      11       8     1/1/2022  13/1/2022   Si
# 4           5     982      11       6       8     1/1/2022  30/1/2022   Si
# ...       ...     ...     ...     ...     ...          ...        ...  ...
# 11713   11714     791     117      62      17    28/2/2022  28/2/2022   Si
# 11714   11715    1293     117      62      17    28/2/2022  28/2/2022   Si
# 11715   11716      46     117      62      17    28/2/2022  28/2/2022   Si
# 11716   11717     693     117      62      17    28/2/2022  28/2/2022   Si
# 11717   11718    1313     117      62      17    28/2/2022  28/2/2022   Si
#
# [11718 rows x 8 columns]

# %%
#Mês de Março
for i in range(1,32):
  dia1=str(i)+str('/')+str(3)+str('/2022')
  dia2=str(i)+str('/')+str(3)+str('/2022')
  #Medicina Geral - Consulta
  num_ate += 1
  dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1,num_pac),'ID_blo':np.random.randint(7,9),'ID_med':np.random.randint(1,35),'ID_pro':21,'Data_Chegada':dia1,'Data_Saida':dia2,'Alta':'Si'}
  dados = dados.append(dicionario,ignore_index=True)
  if i<25:
    #Cardiologia - Cirugia
    num_ate += 1
    dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1,num_pac),'ID_blo':56,'ID_med':np.random.randint(49,50),'ID_pro':np.random.randint(79,86),'Data_Chegada':dia1,'Data_Saida':str(i+3)+str('/')+str(3)+str('/2022'),'Alta':'Si'}
    dados = dados.append(dicionario,ignore_index=True)
    #Oftalmologia - Cirugia
    num_ate += 1
    dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1,num_pac),'ID_blo':57,'ID_med':np.random.randint(51,53),'ID_pro':np.random.randint(87,100),'Data_Chegada':dia1,'Data_Saida':str(i+2)+str('/')+str(3)+str('/2022'),'Alta':'Si'}
    dados = dados.append(dicionario,ignore_index=True)
    #Oncologia - Cirugia e Quimioterapia
    num_ate += 1
    dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1,num_pac),'ID_blo':np.random.randint(54,55),'ID_med':np.random.randint(54,61),'ID_pro':np.random.randint(24,31),'Data_Chegada':dia1,'Data_Saida':str(i+2)+str('/')+str(3)+str('/2022'),'Alta':'Si'}
    dados = dados.append(dicionario,ignore_index=True)
    #Neumonologia - Cirugia
    num_ate += 1
    dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1,num_pac),'ID_blo':63,'ID_med':np.random.randint(62,64),'ID_pro':np.random.randint(101,104),'Data_Chegada':dia1,'Data_Saida':str(i+1)+str('/')+str(3)+str('/2022'),'Alta':'Si'}
    dados = dados.append(dicionario,ignore_index=True)
    #Infectologia - Cirugia
    num_ate += 1
    dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1,num_pac),'ID_blo':np.random.randint(124,125),'ID_med':np.random.randint(65,66),'ID_pro':np.random.randint(111,118),'Data_Chegada':dia1,'Data_Saida':str(i)+str('/')+str(3)+str('/2022'),'Alta':'Si'}
    dados = dados.append(dicionario,ignore_index=True)
    #Plástica - Cirugia
    num_ate += 1
    dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1,num_pac),'ID_blo':62,'ID_med':np.random.randint(67,69),'ID_pro':np.random.randint(53,62),'Data_Chegada':dia1,'Data_Saida':str(i+2)+str('/')+str(3)+str('/2022'),'Alta':'Si'}
    dados = dados.append(dicionario,ignore_index=True)
    #CODVID
    num_ate += 1
    dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1,num_pac),'ID_blo':np.random.randint(10,12),'ID_med':np.random.randint(1,35),'ID_pro':8,'Data_Chegada':dia1,'Data_Saida':str(i+2)+str('/')+str(3)+str('/2022'),'Alta':'Si'}
    dados = dados.append(dicionario,ignore_index=True)
    #Ortopedia - Cirugia
    num_ate += 1
    dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1,num_pac),'ID_blo':53,'ID_med':np.random.randint(43,45),'ID_pro':np.random.randint(45,52),'Data_Chegada':dia1,'Data_Saida':str(i+1)+str('/')+str(3)+str('/2022'),'Alta':'Si'}
    dados = dados.append(dicionario,ignore_index=True)
  #Ginecologia e obstetrícia - Cirugia
  #Solo Mujeres para Parto e Ceraria Pacientes(31-43)
  if i<=7:
    #3 Cirugias por dia
    num_ate += 1
    dicionario = {'ID_ate':num_ate,'ID_pac':i+30,'ID_blo':np.random.randint(58,61),'ID_med':np.random.randint(38,42),'ID_pro':np.random.randint(22,23),'Data_Chegada':dia1,'Data_Saida':str(i+3)+str('/')+str(3)+str('/2022'),'Alta':'Si'}
    dados = dados.append(dicionario,ignore_index=True)
    if i<=3:
      num_ate += 1
      dicionario = {'ID_ate':num_ate,'ID_pac':(i+30)+7,'ID_blo':np.random.randint(58,61),'ID_med':np.random.randint(38,42),'ID_pro':np.random.randint(22,23),'Data_Chegada':dia1,'Data_Saida':str(i+3)+str('/')+str(3)+str('/2022'),'Alta':'Si'}
      dados = dados.append(dicionario,ignore_index=True)
      num_ate += 1
      dicionario = {'ID_ate':num_ate,'ID_pac':(i+30)+10,'ID_blo':np.random.randint(58,61),'ID_med':np.random.randint(38,42),'ID_pro':np.random.randint(22,23),'Data_Chegada':dia1,'Data_Saida':str(i+3)+str('/')+str(3)+str('/2022'),'Alta':'Si'}
      dados = dados.append(dicionario,ignore_index=True)
  for j in range(1,25):
    if j<3:
      #Psiquiatria - Tratamento
      num_ate += 1
      dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1,num_pac),'ID_blo':np.random.randint(51,52),'ID_med':np.random.randint(36,37),'ID_pro':np.random.randint(105,110),'Data_Chegada':dia1,'Data_Saida':dia1,'Alta':'Si'}
      dados = dados.append(dicionario,ignore_index=True)
    if j<=4 :
      #Girugia Geral
      num_ate += 1
      dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1,num_pac),'ID_blo':np.random.randint(10,12),'ID_med':np.random.randint(1,35),'ID_pro':np.random.randint(1,8),'Data_Chegada':dia1,'Data_Saida':str(j)+str('/')+str(3)+str('/2022'),'Alta':'Si'}
      dados = dados.append(dicionario,ignore_index=True)
    if i <= 6:
      #Ortopedia - Consulta
      num_ate += 1
      dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1,num_pac),'ID_blo':np.random.randint(47,48),'ID_med':np.random.randint(43,45),'ID_pro':13,'Data_Chegada':dia1,'Data_Saida':dia2,'Alta':'Si'}
      dados = dados.append(dicionario,ignore_index=True)
      #Pediatria - Consulta
      num_ate += 1
      dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1330,1406),'ID_blo':np.random.randint(4,6),'ID_med':np.random.randint(46,48),'ID_pro':11,'Data_Chegada':dia1,'Data_Saida':dia2,'Alta':'Si'}
      dados = dados.append(dicionario,ignore_index=True)
    if i <= 7:
      #Psiquiatria - Consulta
      num_ate += 1
      dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1,num_pac),'ID_blo':np.random.randint(51,52),'ID_med':np.random.randint(36,37),'ID_pro':14,'Data_Chegada':dia1,'Data_Saida':dia2,'Alta':'Si'}
      dados = dados.append(dicionario,ignore_index=True)
      #Ginecologia e obstetrícia - Consulta
      num_ate += 1
      dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1,num_pac),'ID_blo':np.random.randint(44,46),'ID_med':np.random.randint(38,42),'ID_pro':15,'Data_Chegada':dia1,'Data_Saida':dia2,'Alta':'Si'}
      dados = dados.append(dicionario,ignore_index=True)
    if i <= 12:
      #Cardiologia - Consulta
      num_ate += 1
      dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1,num_pac),'ID_blo':np.random.randint(42,43),'ID_med':np.random.randint(49,50),'ID_pro':20,'Data_Chegada':dia1,'Data_Saida':dia2,'Alta':'Si'}
      dados = dados.append(dicionario,ignore_index=True)
      #Oftalmologia - Consulta
      num_ate += 1
      dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1,num_pac),'ID_blo':np.random.randint(49,50),'ID_med':np.random.randint(51,53),'ID_pro':12,'Data_Chegada':dia1,'Data_Saida':dia2,'Alta':'Si'}
      dados = dados.append(dicionario,ignore_index=True)
      #Oncologia - Consulta
      num_ate += 1
      dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1,num_pac),'ID_blo':np.random.randint(120,123),'ID_med':np.random.randint(54,61),'ID_pro':16,'Data_Chegada':dia1,'Data_Saida':dia2,'Alta':'Si'}
      dados = dados.append(dicionario,ignore_index=True)
    if i<=18:
      #Infectologia - Consulta
      num_ate += 1
      dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1,num_pac),'ID_blo':np.random.randint(118,119),'ID_med':np.random.randint(65,66),'ID_pro':18,'Data_Chegada':dia1,'Data_Saida':dia2,'Alta':'Si'}
      dados = dados.append(dicionario,ignore_index=True)
      #Plástica - Consulta
      num_ate += 1
      dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1,num_pac),'ID_blo':np.random.randint(40,41),'ID_med':np.random.randint(67,69),'ID_pro':19,'Data_Chegada':dia1,'Data_Saida':dia2,'Alta':'Si'}
      dados = dados.append(dicionario,ignore_index=True)
    if i <= 25:
      #Radiografias e Imagem
      num_ate += 1
      dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1,num_pac),'ID_blo':np.random.randint(114,116),'ID_med':np.random.randint(54,61),'ID_pro':np.random.randint(63,78),'Data_Chegada':dia1,'Data_Saida':dia2,'Alta':'Si'}
      dados = dados.append(dicionario,ignore_index=True)
    if i<= 32:
      #Neumonologia - Consulta
      num_ate += 1
      dicionario = {'ID_ate':num_ate,'ID_pac':np.random.randint(1,num_pac),'ID_blo':117,'ID_med':np.random.randint(62,64),'ID_pro':17,'Data_Chegada':dia1,'Data_Saida':dia2,'Alta':'Si'}
      dados = dados.append(dicionario,ignore_index=True)
    if i<=25 :
      #Quimioterapia - 3 dias na semana
      pac = np.random.randint(1,num_pac)
      #Dialiais - 4 dias na semana
      pac2 = np.random.randint(1,num_pac)
      #Hemodiálise Portador Hiv - 3 dias na semana
      pac3 = np.random.randint(1,num_pac)
      if i==3 or i==10 or i==17 or i==24:
        d1=str(i)+str('/')+str(3)+str('/2022')
        d2=str(i)+str('/')+str(3)+str('/2022')
        num_ate += 1
        dicionario = {'ID_ate':num_ate,'ID_pac':pac,'ID_blo':np.random.randint(54,55),'ID_med':np.random.randint(54,61),'ID_pro':9,'Data_Chegada':d1,'Data_Saida':d2,'Alta':'Si'}
        dados = dados.append(dicionario,ignore_index=True)
        num_ate += 1
        dicionario = {'ID_ate':num_ate,'ID_pac':pac2,'ID_blo':np.random.randint(54,55),'ID_med':np.random.randint(54,61),'ID_pro':31,'Data_Chegada':d1,'Data_Saida':d2,'Alta':'Si'}
        dados = dados.append(dicionario,ignore_index=True)
        d1=str(i+1)+str('/')+str(3)+str('/2022')
        d2=str(i+1)+str('/')+str(3)+str('/2022')
        num_ate += 1
        dicionario = {'ID_ate':num_ate,'ID_pac':pac2,'ID_blo':np.random.randint(54,55),'ID_med':np.random.randint(54,61),'ID_pro':31,'Data_Chegada':d1,'Data_Saida':d2,'Alta':'Si'}
        dados = dados.append(dicionario,ignore_index=True)
        num_ate += 1
        dicionario = {'ID_ate':num_ate,'ID_pac':pac3,'ID_blo':np.random.randint(124,125),'ID_med':np.random.randint(65,66),'ID_pro':119,'Data_Chegada':d1,'Data_Saida':d2,'Alta':'Si'}
        dados = dados.append(dicionario,ignore_index=True)
        d1=str(i+2)+str('/')+str(3)+str('/2022')
        d2=str(i+2)+str('/')+str(3)+str('/2022')
        num_ate += 1
        dicionario = {'ID_ate':num_ate,'ID_pac':pac,'ID_blo':np.random.randint(54,55),'ID_med':np.random.randint(54,61),'ID_pro':9,'Data_Chegada':d1,'Data_Saida':d2,'Alta':'Si'}
        dados = dados.append(dicionario,ignore_index=True)
        num_ate += 1
        dicionario = {'ID_ate':num_ate,'ID_pac':pac2,'ID_blo':np.random.randint(54,55),'ID_med':np.random.randint(54,61),'ID_pro':31,'Data_Chegada':d1,'Data_Saida':d2,'Alta':'Si'}
        dados = dados.append(dicionario,ignore_index=True)
        num_ate += 1
        dicionario = {'ID_ate':num_ate,'ID_pac':pac3,'ID_blo':np.random.randint(124,125),'ID_med':np.random.randint(65,66),'ID_pro':119,'Data_Chegada':d1,'Data_Saida':d2,'Alta':'Si'}
        dados = dados.append(dicionario,ignore_index=True)
        d1=str(i+4)+str('/')+str(3)+str('/2022')
        d2=str(i+4)+str('/')+str(3)+str('/2022')
        num_ate += 1
        dicionario = {'ID_ate':num_ate,'ID_pac':pac,'ID_blo':np.random.randint(54,55),'ID_med':np.random.randint(54,61),'ID_pro':9,'Data_Chegada':d1,'Data_Saida':d2,'Alta':'Si'}
        dados = dados.append(dicionario,ignore_index=True)
        num_ate += 1
        dicionario = {'ID_ate':num_ate,'ID_pac':pac2,'ID_blo':np.random.randint(54,55),'ID_med':np.random.randint(54,61),'ID_pro':31,'Data_Chegada':d1,'Data_Saida':d2,'Alta':'Si'}
        dados = dados.append(dicionario,ignore_index=True)
        num_ate += 1
        dicionario = {'ID_ate':num_ate,'ID_pac':pac3,'ID_blo':np.random.randint(124,125),'ID_med':np.random.randint(65,66),'ID_pro':119,'Data_Chegada':d1,'Data_Saida':d2,'Alta':'Si'}
        dados = dados.append(dicionario,ignore_index=True)
#Pediatria - Cirugia ******** #Não temos no Hospital
print(dados)
# Out:
#        ID_ate  ID_pac  ID_blo  ID_med  ID_pro Data_Chegada Data_Saida Alta
# 0           1       1       7       1       7     1/1/2022   1/1/2022   Si
# 1           2    1163      10       5       8     1/1/2022   8/1/2022   Si
# 2           3     644      11      21       8     1/1/2022  15/1/2022   Si
# 3           4    1205      10      11       8     1/1/2022  13/1/2022   Si
# 4           5     982      11       6       8     1/1/2022  30/1/2022   Si
# ...       ...     ...     ...     ...     ...          ...        ...  ...
# 16791   16792     538     117      63      17    31/3/2022  31/3/2022   Si
# 16792   16793     420     117      62      17    31/3/2022  31/3/2022   Si
# 16793   16794      38     117      62      17    31/3/2022  31/3/2022   Si
# 16794   16795     309     117      63      17    31/3/2022  31/3/2022   Si
# 16795   16796    1118     117      63      17    31/3/2022  31/3/2022   Si
#
# [16796 rows x 8 columns]

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16796 entries, 0 to 16795
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID_ate        16796 non-null  int64
#  1   ID_pac        16796 non-null  int64
#  2   ID_blo        16796 non-null  int64
#  3   ID_med        16796 non-null  int64
#  4   ID_pro        16796 non-null  int64
#  5   Data_Chegada  16796 non-null  object
#  6   Data_Saida    16796 non-null  object
#  7   Alta          16796 non-null  object
# dtypes: int64(5), object(3)
# memory usage: 1.0+ MB

# %%
#Exportando Dados
dados.to_csv('dadoshospital1.csv')
